# %% [markdown]
# <a href="https://colab.research.google.com/github/omerzamir/Decision-Tree-house-votes-public/blob/master/POC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install alpha_vantage

# %% [markdown]
# https://rapidapi.com/newscatcher-api-newscatcher-api-default/api/google-news?endpoint=apiendpoint_5e0fa919-2494-4b20-a212-d186b7e8c3d8
#
#
# https://www.alphavantage.co/documentation/

# %%
from alpha_vantage.timeseries import TimeSeries
import matplotlib.pyplot as plt

ts = TimeSeries(key='', output_format='pandas')

data, meta_data = ts.get_intraday(symbol='AAPL',interval='1min', outputsize='full')

data, meta_data = ts.get_daily_adjusted(symbol='AAPL')

data['4. close'].plot()
plt.show()

# %%
import requests

url = "https://google-news.p.rapidapi.com/v1/topic_headlines"

querystring = {"lang":"en","country":"US","topic":"technology"}

headers = {
    'x-rapidapi-key': "c412a8d9b0mshd1b16912b0469d6p1f1edcjsnd23dc0376edc",
    'x-rapidapi-host': "google-news.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"feed":{"title":"Technology - Latest - Google News","updated":"Thu, 17 Dec 2020 13:45:41 GMT","link":"https://news.google.com/topics/CAAqJggKIiBDQkFTRWdvSUwyMHZNRGRqTVhZU0FtVnVHZ0pWVXlnQVAB?ceid=US:en&hl=en-US&gl=US","language":"en-US","subtitle":"Google News","rights":"2020 Google Inc."},"articles":[{"id":"52781246124683","title":"Facebook slams Apple privacy change again, suggesting it will kill free apps - CNBC","link":"https://news.google.com/__?oc=5","published":"Thu, 17 Dec 2020 09:00:00 GMT","sub_articles":[{"url":"https://news.google.com/__i/rss/rd/articles/CBMiaGh0dHBzOi8vd3d3LmNuYmMuY29tLzIwMjAvMTIvMTcvZmFjZWJvb2stY3JpdGljaXplcy1hcHBsZS1wcml2YWN5LWNoYW5nZS1pbi1zZWNvbmQ
# ...

# %%
import json

json_dictionary = json.loads(response.text)
# Loop through dictionary keys to access each article
for item in json_dictionary['articles']:
    print("Title:", item['title'], "Date:", item['published'])
# Out:
# Title: Facebook slams Apple privacy change again, suggesting it will kill free apps - CNBC Date: Thu, 17 Dec 2020 09:00:00 GMT
# Title: Here’s the best look yet at Samsung’s Galaxy Buds Pro wireless earbuds - The Verge Date: Thu, 17 Dec 2020 09:30:23 GMT
# Title: Three million users installed 28 malicious Chrome or Edge extensions - ZDNet Date: Thu, 17 Dec 2020 02:30:00 GMT
# Title: 'Death Stranding' PC update adds 'Cyberpunk 2077' missions and gear - Engadget Date: Thu, 17 Dec 2020 12:29:13 GMT
# Title: Motorola's next cheap phone is said to come with a surprisingly high-res camera - TechRadar Date: Thu, 17 Dec 2020 09:52:00 GMT
# Title: PSA: How to switch off AirPods Max without Apple ‘bra’ case - 9to5Mac Date: Thu, 17 Dec 2020 12:09:00 GMT
# Title: Xbox Series X just got an exclusive game to fight the PS5 - Tom's Guide Date: Thu, 17 Dec 2020 06:00:00 GMT
# ...

# %%
url = "https://google-news.p.rapidapi.com/v1/search"

querystring = {"q":"Apple","country":"US","lang":"en"}

headers = {
    'x-rapidapi-key': "c412a8d9b0mshd1b16912b0469d6p1f1edcjsnd23dc0376edc",
    'x-rapidapi-host': "google-news.p.rapidapi.com"
    }

apple_response = requests.request("GET", url, headers=headers, params=querystring)

print(apple_response.text)
# Out:
# {"feed":{"title":"\"Apple\" - Google News","updated":"Thu, 17 Dec 2020 13:53:13 GMT","link":"https://news.google.com/search?q=Apple&ceid=US:en&hl=en-US&gl=US","language":"en-US","subtitle":"Google News","rights":"2020 Google Inc."},"articles":[{"id":"52781246124683","title":"Facebook hits back at Apple with second critical newspaper ad - The Verge","link":"https://www.theverge.com/2020/12/17/22180102/facebook-new-newspaper-ad-apple-ios-14-privacy-prompt","published":"Thu, 17 Dec 2020 09:00:00 GMT","sub_articles":[{"url":"https://www.theverge.com/2020/12/17/22180102/facebook-new-newspaper-ad-apple-ios-14-privacy-prompt","title":"Facebook hits back at Apple with second critical newspaper ad","publisher":"The Verge"},{"url":"https://9to5mac.com/2020/12/16/apple-facebook-app-tracking-transparency/","title":"Apple rebuffs Facebook criticism, says iOS anti-tracking features are about \u2019standing up for our users\u2019","publisher":"9to5Mac"},{"url":"https://www.cnet.com/news/facebook-es
# ...
